# %%
import numpy as np 
import pandas as pd 
from pandas import Series, DataFrame 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
restaurant_df = pd.read_csv('DOHMH_Python.csv')

# %%
restaurant_df.head()
# Out:
#                          DBA           BORO BUILDING                STREET  \
# 0                  STARBUCKS      Manhattan       78         SPRING STREET
# 1  110 KENNEDY FRIED CHICKEN  Staten Island      110     VICTORY BOULEVARD
# 2                    HQ CLUB      Manhattan      552      WEST   38 STREET
# 3         RESTAURANT TATIANA       Brooklyn     3152  BRIGHTON    6 STREET
# 4                   KO SUSHI      Manhattan     1329              2 AVENUE
#
#    ZIPCODE          CUISINE  \
# 0  10012.0  Café/Coffee/Tea
# 1  10301.0          Chicken
# 2  10018.0         American
# 3  11235.0          Russian
# 4  10021.0         Japanese
#
#                                               ACTION VIOLATION  \
# 0    Violations were cited in the following area(s).       10B
# 1  Establishment Closed by DOHMH.  Violations wer...       02C
# 2    Violations were cited in the following area(s).       04N
# 3    Violations were cited in the following area(s).       10F
# 4    Violations were cited in the following area(s).       10B
#
#                                VIOLATION_DESCRIPTION CRITICAL_FLAG  SCORE  \
# 0  Plumbing not properly installed or maintained;...             N    9.0
# 1  Hot food item that has been cooked and refrige...             Y   39.0
# 2  Filth flies or food/refuse/sewage-associated (...             Y   13.0
# 3  Non-food contact surface improperly constructe...             N   12.0
# 4  Plumbing not properly installed or maintained;...             N    7.0
#
#   GRADE                                INSPECTION_TYPE
# 0     A          Cycle Inspection / Initial Inspection
# 1   NaN  Pre-permit (Operational) / Initial Inspection
# 2     A          Cycle Inspection / Initial Inspection
# 3     A               Cycle Inspection / Re-inspection
# 4   NaN          Cycle Inspection / Initial Inspection

# %%
restaurant_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316935 entries, 0 to 316934
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   DBA                    316935 non-null  object
#  1   BORO                   316935 non-null  object
#  2   BUILDING               316875 non-null  object
#  3   STREET                 316935 non-null  object
#  4   ZIPCODE                314882 non-null  float64
#  5   CUISINE                316935 non-null  object
#  6   ACTION                 316935 non-null  object
#  7   VIOLATION              313672 non-null  object
#  8   VIOLATION_DESCRIPTION  311073 non-null  object
#  9   CRITICAL_FLAG          311073 non-null  object
#  10  SCORE                  304473 non-null  float64
#  11  GRADE                  160251 non-null  object
#  12  INSPECTION_TYPE        316935 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 31.4+ MB

# %%
restaurant_df.describe()
# Out:
#              ZIPCODE          SCORE
# count  314882.000000  304473.000000
# mean    10542.432562      20.587136
# std       564.366569      14.943915
# min     10001.000000      -1.000000
# 25%     10018.000000      11.000000
# 50%     10310.000000      16.000000
# 75%     11215.000000      26.000000
# max     12345.000000     164.000000

# %% [markdown]
# From this initial exploration, what I learned was that there are a total of 13 columns and roughly 300,000 entries. Most of the data is qualitative, with restaurant score being the most important quantitative column.

# %% [markdown]
# Each restaurant also has a numeric score based on the number and type of violation it receives. There are three overarching categories of violations with a point value associated with them:

# %% [markdown]
# General - 2 points |
# Critical - 5 points |
# Public Health Hazard - 7 points

# %% [markdown]
# The final score is an accumulation of the sum of the points, and thus a letter grade is assigned. Restaurants with scores of 0-13 points are given an A, 14-27 points are given a B, and 28+ points are given a C.

# %% [markdown]
# Even though I cleaned the data in Excel prior, using the describe() function provided more insight. A major mistake I found is that the minimum score is -1, which seems like an unlikely mistake. I will remove that entry with the code below.

# %%
#see the rows that have a restaurant with a score of -1 
restaurant_df[restaurant_df.SCORE == -1]
# Out:
#                                         DBA       BORO BUILDING  \
# 2666                       ELI'S ESSENTIALS  Manhattan     1291
# 5174                              PERK KAFE  Manhattan      534
# 10105                       THE CORNER CAFE  Manhattan      729
# 10838                         TANG PAVILION  Manhattan       65
# 12244                                 KENKA  Manhattan       25
# ...                                     ...        ...      ...
# 305553                           YURI SUSHI  Manhattan      374
# 306761                        TANG PAVILION  Manhattan       65
# 313629                                KENKA  Manhattan       25
# 315276                KAI FAN ASIAN CUISINE      Bronx     3717
# 315376  FORDHAM POD EXPRESS AT KEATING HALL      Bronx      441
#
#                    STREET  ZIPCODE                         CUISINE  \
# 2666     LEXINGTON AVENUE  10028.0                        American
# 5174     EAST   14 STREET  10009.0                 Café/Coffee/Tea
# 10105            6 AVENUE  10010.0  Sandwiches/Salads/Mixed Buffet
# 10838    WEST   55 STREET  10019.0                         Chinese
# 12244      ST MARKS PLACE  10003.0                        Japanese
# ...                   ...      ...                             ...
# 305553   WEST   46 STREET  10036.0                        Japanese
# 306761   WEST   55 STREET  10019.0                         Chinese
# 313629     ST MARKS PLACE  10003.0                        Japanese
# 315276   RIVERDALE AVENUE  10463.0                   Jewish/Kosher
# 315376  EAST FORDHAM ROAD  10458.0                 Café/Coffee/Tea
#
#                                                    ACTION VIOLATION  \
# 2666      Violations were cited in the following area(s).       08A
# 5174      Violations were cited in the following area(s).       05A
# 10105     Violations were cited in the following area(s).       04L
# 10838     Violations were cited in the following area(s).       04L
# 12244     Violations were cited in the following area(s).       06D
# ...                                                   ...       ...
# 305553    Violations were cited in the following area(s).       06D
# 306761    Violations were cited in the following area(s).       06D
# 313629    Violations were cited in the following area(s).       10H
# 315276    Violations were cited in the following area(s).       06D
# 315376  Establishment Closed by DOHMH.  Violations wer...       05A
#
#                                     VIOLATION_DESCRIPTION CRITICAL_FLAG  \
# 2666    Facility not vermin proof. Harborage or condit...             N
# 5174       Sewage disposal system improper or unapproved.             Y
# 10105   Evidence of mice or live mice present in facil...             Y
# 10838   Evidence of mice or live mice present in facil...             Y
# 12244   Food contact surface not properly washed, rins...             Y
# ...                                                   ...           ...
# 305553  Food contact surface not properly washed, rins...             Y
# 306761  Food contact surface not properly washed, rins...             Y
# 313629  Proper sanitization not provided for utensil w...             N
# 315276  Food contact surface not properly washed, rins...             Y
# 315376     Sewage disposal system improper or unapproved.             Y
#
#         SCORE GRADE                                INSPECTION_TYPE
# 2666     -1.0   NaN          Cycle Inspection / Initial Inspection
# 5174     -1.0   NaN  Pre-permit (Operational) / Initial Inspection
# 10105    -1.0   NaN          Cycle Inspection / Initial Inspection
# 10838    -1.0     C               Cycle Inspection / Re-inspection
# 12244    -1.0   NaN          Cycle Inspection / Initial Inspection
# ...       ...   ...                                            ...
# 305553   -1.0   NaN          Cycle Inspection / Initial Inspection
# 306761   -1.0     C               Cycle Inspection / Re-inspection
# 313629   -1.0   NaN          Cycle Inspection / Initial Inspection
# 315276   -1.0     B               Cycle Inspection / Re-inspection
# 315376   -1.0   NaN               Cycle Inspection / Re-inspection
#
# [117 rows x 13 columns]

# %%
#delete the rows with score of -1 
restaurant_df = restaurant_df.drop(restaurant_df[restaurant_df.SCORE == -1].index)

# %%
#check my work using describe function again 
restaurant_df.describe()
# Out:
#              ZIPCODE          SCORE
# count  314768.000000  304356.000000
# mean    10542.541316      20.595434
# std       564.379829      14.940791
# min     10001.000000       0.000000
# 25%     10018.000000      11.000000
# 50%     10310.000000      16.000000
# 75%     11215.000000      26.000000
# max     12345.000000     164.000000

# %%
#store this new df to use in future notebooks - Analysis of Restaurant Grades 
# %store restaurant_df
# Out:
# Stored 'restaurant_df' (DataFrame)

# %% [markdown]
# See http://www.hicathy.com/restaurant_data/index.php for a full analysis.
